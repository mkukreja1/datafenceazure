# %%
from delta.tables import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.types import StructType, StructField, IntegerType, StringType,array,ArrayType,DateType,TimestampType
from pyspark.sql import functions as f
from pyspark.sql.functions import udf
import hashlib
import datetime
from datetime import timedelta
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
STORAGE_ACCOUNT="traininglakehouse"
ADLS_KEY="***************************"

spark.conf.set("fs.azure.account.key."+STORAGE_ACCOUNT+".blob.core.windows.net", ADLS_KEY)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT order_date FROM store_orders;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
SELECT order_date FROM esalesns;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
SELECT email FROM store_customers;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
DESCRIBE products
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
DESCRIBE store_orders
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
select customer_name,country from store_customers
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
select customer_name,country from esalesns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
SELECT customer_name FROM store_customers WHERE email = 'phasellus.vitae@vitae.co.uk'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
SELECT order_number, order_date,sale_price FROM store_orders WHERE order_number in (500, 1254, 1501, 2234, 2345)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
select customer_name, address, phone, credit_card from store_customers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>address</th><th>phone</th><th>credit_card</th></tr></thead><tbody><tr><td>Hannah Ferrell</td><td>65897909eb6c663ef29d355955450f72617c9902883f71ea143c90f081266c11</td><td>73c857e4eb80dde212251499a01bc3d2c930dc741871b4447df5274a4347490d</td><td>0940976aa4def8d6a038d642c5abf9fb05b7c092d7cf6a1a829a07e39671b191</td></tr><tr><td>May Bentley</td><td>0500ea20e89af55a6fac6ef0bec4499e6fb414f407af39c7ede5099d985b2d62</td><td>004ef30cb39b1ede61ac5d0ee87b6f89d1f895c1e22167704f42769d642861ce</td><td>0c9c69f0e315de01f2074e5d77417be0ef26937447c6755061ca2ad9e11c4500</td></tr><tr><td>Nelle Frost</td><td>258ee2462b43b6e4db568d480cc72d20ea3887b7b7798ff09fde540444f50461</td><td>db693e6d5ab3a2d32d87b89dca3e1bfeb377338551a6fc68dc5d3d6595dd16fe</td><td>517bdccaf06ad0146c4b9cd334850e1aeda8818f7f8961f5900f359e0e6bcd03</td></tr><tr><td>Ayanna Morton</td><td>0358e5a17f7adf9e2e65123e40090402ef8f3cf4144335a7cc6659f7ac5e07c2</td><td>1e16545ab23f02231d303129e8bf570724c7ca0ca65c3014a82565965d9760eb</td><td>85adb57dda2675d6b6a2be0f1d6baa8415e1eca86d09e19c2a8764c52c98309e</td></tr><tr><td>Faith Hooper</td><td>cb11233c9ebabec5ab5739d74eb75da22ac6a185a10bfc06f1326c1cbf655df8</td><td>727770f831c30984032f384c0f44f277659277c11329f2d3ab7c0701b657f6b4</td><td>62f70b8858dcf1090fa46648749e2517ce9b7d5b6722e41798c5af20653abaa6</td></tr><tr><td>Sage Bauer</td><td>a42c76773611d481f8c1f2b09b4a0ede3ccf90eceed3e2e465b3cfa07b8db20b</td><td>fbcfda7b8f07af3a1c6f72d5842d6d37ce6ad63fa4bbb3ab3b7781fac3a4a070</td><td>a07e4417dd3fa177a863ac25606eb58f6ddc3366d3c99c16583c5e1ec4d06cff</td></tr><tr><td>Lionel Dillon</td><td>940b40d376be962fb4e47a965ecf